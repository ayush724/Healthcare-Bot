# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./dataset.csv')
df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16 Symptom_17
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
for col in df.columns:   
    df[col] = df[col].str.replace('_',' ')
df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin rash   nodal skin eruptions
# 1  Fungal infection   skin rash   nodal skin eruptions    dischromic  patches
# 2  Fungal infection     itching   nodal skin eruptions    dischromic  patches
# 3  Fungal infection     itching              skin rash    dischromic  patches
# 4  Fungal infection     itching              skin rash   nodal skin eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic  patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16 Symptom_17
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
symptoms= df.columns[1:18]
print(symptoms)
# Out:
# Index(['Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4', 'Symptom_5',
#        'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9', 'Symptom_10',
#        'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14', 'Symptom_15',
#        'Symptom_16', 'Symptom_17'],
#       dtype='object')

# %%
df['All_Symptoms'] = df.apply(lambda row: ','.join(row[symptoms].dropna()), axis=1)
df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin rash   nodal skin eruptions
# 1  Fungal infection   skin rash   nodal skin eruptions    dischromic  patches
# 2  Fungal infection     itching   nodal skin eruptions    dischromic  patches
# 3  Fungal infection     itching              skin rash    dischromic  patches
# 4  Fungal infection     itching              skin rash   nodal skin eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic  patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16 Symptom_17                                       All_Symptoms
# 0        NaN        NaN  itching, skin rash, nodal skin eruptions, disc...
# 1        NaN        NaN   skin rash, nodal skin eruptions, dischromic  ...
# 2        NaN        NaN  itching, nodal skin eruptions, dischromic  pat...
# 3        NaN        NaN            itching, skin rash, dischromic  patches
# 4        NaN        NaN           itching, skin rash, nodal skin eruptions

# %%
df.drop(symptoms, axis=1, inplace=True)

# %%
df.head()
# Out:
#             Disease                                       All_Symptoms
# 0  Fungal infection  itching, skin rash, nodal skin eruptions, disc...
# 1  Fungal infection   skin rash, nodal skin eruptions, dischromic  ...
# 2  Fungal infection  itching, nodal skin eruptions, dischromic  pat...
# 3  Fungal infection            itching, skin rash, dischromic  patches
# 4  Fungal infection           itching, skin rash, nodal skin eruptions

# %%
df1 = pd.read_csv('./symptom_precaution.csv')
df1.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %%
precautions= df1.columns[1:5]
print(precautions)
# Out:
# Index(['Precaution_1', 'Precaution_2', 'Precaution_3', 'Precaution_4'], dtype='object')

# %%
df1['All_Precautions'] = df1.apply(lambda row: ','.join(row[precautions].dropna()), axis=1)
df1.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4  \
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths
#
#                                      All_Precautions
# 0  stop irritation,consult nearest hospital,stop ...
# 1  Consult nearest hospital,avoid oily food,avoid...
# 2  apply calamine,cover area with bandage,use ice...
# 3  reduce stress,exercise,eat healthy,get proper ...
# 4  wash hands with warm soapy water,stop bleeding...

# %%
df1.drop(precautions, axis=1, inplace=True)

# %%
df1.head()
# Out:
#           Disease                                    All_Precautions
# 0   Drug Reaction  stop irritation,consult nearest hospital,stop ...
# 1         Malaria  Consult nearest hospital,avoid oily food,avoid...
# 2         Allergy  apply calamine,cover area with bandage,use ice...
# 3  Hypothyroidism  reduce stress,exercise,eat healthy,get proper ...
# 4       Psoriasis  wash hands with warm soapy water,stop bleeding...

# %%
df2 = pd.merge(df ,df1 ,on='Disease',how='inner')

# %%
df2.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  itching, skin rash, nodal skin eruptions, disc...
# 1  Fungal infection   skin rash, nodal skin eruptions, dischromic  ...
# 2  Fungal infection  itching, nodal skin eruptions, dischromic  pat...
# 3  Fungal infection            itching, skin rash, dischromic  patches
# 4  Fungal infection           itching, skin rash, nodal skin eruptions
#
#                                      All_Precautions
# 0  bath twice,use detol or neem in bathing water,...
# 1  bath twice,use detol or neem in bathing water,...
# 2  bath twice,use detol or neem in bathing water,...
# 3  bath twice,use detol or neem in bathing water,...
# 4  bath twice,use detol or neem in bathing water,...

# %%
def pre(x):
    return "The precautions to take: " + x

# %%
df2.All_Precautions = df2.All_Precautions.apply(pre)

# %%
df2.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  itching, skin rash, nodal skin eruptions, disc...
# 1  Fungal infection   skin rash, nodal skin eruptions, dischromic  ...
# 2  Fungal infection  itching, nodal skin eruptions, dischromic  pat...
# 3  Fungal infection            itching, skin rash, dischromic  patches
# 4  Fungal infection           itching, skin rash, nodal skin eruptions
#
#                                      All_Precautions
# 0  The precautions to take: bath twice,use detol ...
# 1  The precautions to take: bath twice,use detol ...
# 2  The precautions to take: bath twice,use detol ...
# 3  The precautions to take: bath twice,use detol ...
# 4  The precautions to take: bath twice,use detol ...

# %%
df2.All_Precautions[0]
# Out:
# 'The precautions to take: bath twice,use detol or neem in bathing water,keep infected area dry,use clean cloths'

# %%
df2.All_Symptoms = df2.All_Symptoms.str.replace(',', ' ')

# %%
df2.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  itching  skin rash  nodal skin eruptions  disc...
# 1  Fungal infection   skin rash  nodal skin eruptions  dischromic  ...
# 2  Fungal infection  itching  nodal skin eruptions  dischromic  pat...
# 3  Fungal infection            itching  skin rash  dischromic  patches
# 4  Fungal infection           itching  skin rash  nodal skin eruptions
#
#                                      All_Precautions
# 0  The precautions to take: bath twice,use detol ...
# 1  The precautions to take: bath twice,use detol ...
# 2  The precautions to take: bath twice,use detol ...
# 3  The precautions to take: bath twice,use detol ...
# 4  The precautions to take: bath twice,use detol ...

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
import string

# %%
rg = df2.copy()

# %%
# the stop words for removing
victim = set([
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd",
    'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers',
    'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which',
    'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been',
    'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if',
    'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between',
    'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out',
    'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why',
    'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not',
    'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't",
    'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn',
    "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't",
    'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',"mustn't", 'needn', "needn't", 'shan', "shan't",
    'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", "ff", "suffering",
    "I", "and"
])

# the Preprocessing function use to preprocess the text input and the train samples
def preprocess_text(text):
    text = text.lower()

    text = text.translate(str.maketrans('', '', string.punctuation))

    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(text)

    tokens = [word for word in tokens if word not in victim]

    return tokens

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words="english")

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
rg.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  itching  skin rash  nodal skin eruptions  disc...
# 1  Fungal infection   skin rash  nodal skin eruptions  dischromic  ...
# 2  Fungal infection  itching  nodal skin eruptions  dischromic  pat...
# 3  Fungal infection            itching  skin rash  dischromic  patches
# 4  Fungal infection           itching  skin rash  nodal skin eruptions
#
#                                      All_Precautions
# 0  The precautions to take: bath twice,use detol ...
# 1  The precautions to take: bath twice,use detol ...
# 2  The precautions to take: bath twice,use detol ...
# 3  The precautions to take: bath twice,use detol ...
# 4  The precautions to take: bath twice,use detol ...

# %%
rg.All_Symptoms = rg.All_Symptoms.apply(preprocess_text)

# %%
rg.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  [itching, skin, rash, nodal, skin, eruptions, ...
# 1  Fungal infection  [skin, rash, nodal, skin, eruptions, dischromi...
# 2  Fungal infection  [itching, nodal, skin, eruptions, dischromic, ...
# 3  Fungal infection         [itching, skin, rash, dischromic, patches]
# 4  Fungal infection      [itching, skin, rash, nodal, skin, eruptions]
#
#                                      All_Precautions
# 0  The precautions to take: bath twice,use detol ...
# 1  The precautions to take: bath twice,use detol ...
# 2  The precautions to take: bath twice,use detol ...
# 3  The precautions to take: bath twice,use detol ...
# 4  The precautions to take: bath twice,use detol ...

# %%
rg.All_Symptoms = rg.All_Symptoms.apply(lambda x:' '.join(map(str, x)))

# %%
rg.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  itching skin rash nodal skin eruptions dischro...
# 1  Fungal infection  skin rash nodal skin eruptions dischromic patches
# 2  Fungal infection    itching nodal skin eruptions dischromic patches
# 3  Fungal infection               itching skin rash dischromic patches
# 4  Fungal infection             itching skin rash nodal skin eruptions
#
#                                      All_Precautions
# 0  The precautions to take: bath twice,use detol ...
# 1  The precautions to take: bath twice,use detol ...
# 2  The precautions to take: bath twice,use detol ...
# 3  The precautions to take: bath twice,use detol ...
# 4  The precautions to take: bath twice,use detol ...

# %%
vectors = cv.fit_transform(rg["All_Symptoms"])

# %%
rg1 = rg.copy()

# %%
cv1 = TfidfVectorizer()
vectors1 = cv1.fit_transform(rg["All_Symptoms"])

# %%
# the unique features
cv.get_feature_names()
# Out:
# c:\Users\ayush\OneDrive\Desktop\Healthcare-Chatbot-main\venv\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['abdomen',
#  'abdominal',
#  'abnormal',
#  'acidity',
#  'acute',
#  'alcohol',
#  'altered',
#  'anal',
#  'anus',
#  'anxiety',
#  'appetite',
#  'balance',
#  'belly',
#  'blackheads',
#  'bladder',
#  'bleeding',
#  'blister',
#  'blood',
#  'bloody',
#  'blurred',
#  'body',
#  'bowel',
#  'breathlessness',
#  'brittle',
#  'bruising',
#  'burning',
#  'calf',
#  'chest',
#  'chills',
#  'cold',
#  'coma',
#  'concentration',
#  'congestion',
#  'constipation',
#  'consumption',
#  'contacts',
#  'continuous',
#  'cough',
#  'cramps',
#  'crust',
#  'dark',
#  'dehydration',
#  'dents',
#  'depression',
#  'diarrhoea',
#  'dischromic',
#  'discomfort',
#  'distention',
#  'distorted',
#  'disturbances',
#  'dizziness',
#  'drying',
#  'dusting',
#  'enlarged',
#  'eruptions',
#  'excessive',
#  'extra',
#  'extremeties',
#  'eyes',
#  'face',
#  'failure',
#  'family',
#  'fast',
#  'fatigue',
#  'feel',
#  'feets',
#  'fever',
#  'filled',
#  'fluid',
#  'foul',
#  'gain',
#  'gases',
#  'hands',
#  'headache',
#  'heart',
#  'high',
#  'hip',
#  'history',
#  'hunger',
#  'increased',
#  'indigestion',
#  'inflammatory',
#  'injections',
#  'internal',
#  'irregular',
#  'irritability',
#  'irritation',
#  'itching',
#  'joint',
#  'joints',
#  'knee',
#  'lack',
#  'legs',
#  'lethargy',
#  'level',
#  'like',
#  'limbs',
#  'lips',
#  'liver',
#  'look',
#  'loss',
#  'lymph',
#  'malaise',
#  'marital',
#  'menstruation',
#  'micturition',
#  'mild',
#  'mood',
#  'movement',
#  'movements',
#  'mucoid',
#  'muscle',
#  'nails',
#  'nausea',
#  'neck',
#  'nodal',
#  'nodes',
#  'nose',
#  'obesity',
#  'ooze',
#  'overload',
#  'pain',
#  'painful',
#  'palpitations',
#  'passage',
#  'patches',
#  'peeling',
#  'phlegm',
#  'pimples',
#  'polyuria',
#  'pressure',
#  'prominent',
#  'puffy',
#  'pus',
#  'rash',
#  'rate',
#  'receiving',
#  'red',
#  'redness',
#  'region',
#  'restlessness',
#  'runny',
#  'rusty',
#  'scurring',
#  'sensorium',
#  'shivering',
#  'silver',
#  'sinus',
#  'skin',
#  'slurred',
#  'small',
#  'smell',
#  'sneezing',
#  'sore',
#  'speech',
#  'spinning',
#  'spots',
#  'spotting',
#  'sputum',
#  'stiff',
#  'stiffness',
#  'stomach',
#  'stool',
#  'sugar',
#  'sunken',
#  'sweating',
#  'swelled',
#  'swelling',
#  'swings',
#  'swollen',
#  'throat',
#  'thyroid',
#  'tingling',
#  'tongue',
#  'toxic',
#  'transfusion',
#  'typhos',
#  'ulcers',
#  'unsteadiness',
#  'unsterile',
#  'urination',
#  'urine',
#  'veins',
#  'vessels',
#  'vision',
#  'visual',
#  'vomiting',
#  'walking',
#  'wasting',
#  'watering',
#  'weakness',
#  'weight',
#  'yellow',
#  'yellowing',
#  'yellowish']

# %%
rg.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  itching skin rash nodal skin eruptions dischro...
# 1  Fungal infection  skin rash nodal skin eruptions dischromic patches
# 2  Fungal infection    itching nodal skin eruptions dischromic patches
# 3  Fungal infection               itching skin rash dischromic patches
# 4  Fungal infection             itching skin rash nodal skin eruptions
#
#                                      All_Precautions
# 0  The precautions to take: bath twice,use detol ...
# 1  The precautions to take: bath twice,use detol ...
# 2  The precautions to take: bath twice,use detol ...
# 3  The precautions to take: bath twice,use detol ...
# 4  The precautions to take: bath twice,use detol ...

# %%
# data = df['All_Symptoms'].values # features
labels = df['Disease'].values # target

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score 
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC  
clf = SVC(kernel='linear')

# %%
data = vectors.copy()
print(vectors1)
# Out:
#   (0, 129)	0.37739481295348326
#   (0, 48)	0.44044545355335174
#   (0, 57)	0.44044545355335174
#   (0, 118)	0.44044545355335174
#   (0, 138)	0.25942204322367196
#   (0, 153)	0.3759751695378639
#   (0, 90)	0.2587265697004888
#   (1, 129)	0.39069783988358725
#   (1, 48)	0.4559709921372228
#   (1, 57)	0.4559709921372228
#   (1, 118)	0.4559709921372228
#   (1, 138)	0.2685665738552906
#   (1, 153)	0.38922815456505644
#   (2, 129)	0.41507505253888166
#   (2, 48)	0.4844208597978338
#   (2, 57)	0.4844208597978338
#   (2, 118)	0.4844208597978338
#   (2, 153)	0.20675683381541218
#   (2, 90)	0.2845586129581271
#   (3, 129)	0.530544350760861
#   (3, 48)	0.6191813961943304
#   (3, 138)	0.36469737996140295
#   (3, 153)	0.2642743029025906
#   (3, 90)	0.3637196782650257
#   (4, 57)	0.5406860615699701
#   :	:
#   (4917, 39)	0.26653470768931453
#   (4918, 84)	0.2953924270546436
#   (4918, 45)	0.2953924270546436
#   (4918, 155)	0.2953924270546436
#   (4918, 55)	0.2953924270546436
#   (4918, 98)	0.2953924270546436
#   (4918, 151)	0.2953924270546436
#   (4918, 130)	0.2953924270546436
#   (4918, 115)	0.4988861697233735
#   (4918, 91)	0.18402516989069134
#   (4918, 125)	0.10232814832851894
#   (4918, 138)	0.17594602151365246
#   (4918, 153)	0.2549950437753391
#   (4919, 123)	0.3530024667865358
#   (4919, 42)	0.3530024667865358
#   (4919, 11)	0.3530024667865358
#   (4919, 158)	0.3530024667865358
#   (4919, 19)	0.3530024667865358
#   (4919, 120)	0.2999628022719806
#   (4919, 197)	0.30188232291254824
#   (4919, 141)	0.2706108579296813
#   (4919, 69)	0.16263877982530076
#   (4919, 78)	0.16949928517921223
#   (4919, 138)	0.21026056840687665
#   (4919, 153)	0.15236321453559815

# %%
x_train, x_test, y_train, y_test = train_test_split(data, labels, train_size = 0.8,random_state=42)
#Train the model using the training sets
clf.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)
print('F1-score% =', f1_score(y_test, y_pred, average='macro')*100, '|', 'Accuracy% =', accuracy_score(y_test, y_pred)*100)
# Out:
# F1-score% = 100.0 | Accuracy% = 100.0

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(vectors1, labels, train_size = 0.8,random_state=42)
#Train the model using the training sets
clf.fit(x_train1, y_train1)

#Predict the response for test dataset
y_pred1 = clf.predict(x_test1)
print('F1-score% =', f1_score(y_test1, y_pred1, average='macro')*100, '|', 'Accuracy% =', accuracy_score(y_test1, y_pred1)*100)
# Out:
# F1-score% = 100.0 | Accuracy% = 100.0

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(vectors1, labels, train_size = 0.8,random_state=42)
rnd_forest = RandomForestClassifier(random_state=42, max_features='sqrt', n_estimators= 500, max_depth=13)
rnd_forest.fit(x_train2,y_train2)
preds=rnd_forest.predict(x_test2)
print('F1-score% =', f1_score(y_test2, preds, average='macro')*100, '|', 'Accuracy% =', accuracy_score(y_test2, preds)*100)
# Out:
# F1-score% = 100.0 | Accuracy% = 100.0

# %%
preprocessed_symptoms2 = preprocess_text("I have back pain dizziness fever and vomiting loss of apettite nausea")
preprocessed_symptoms2 = " ".join(preprocessed_symptoms2)
user2 = cv1.transform([preprocessed_symptoms2])
predict1 = rnd_forest.predict(user2)
print("Disease:", predict1)
predict2=predict1[0]
mat = rg[rg["Disease"] == predict2]
dia = mat.All_Precautions.values[0]
print("Precautions:" , dia)
# Out:
# Disease: ['Cervical spondylosis']
# Precautions: The precautions to take: use heating pad or cold pack,exercise,take otc pain reliver,consult doctor

# %%
preprocessed_symptoms2 = preprocess_text("I have back pain dizziness fever and vomiting")
preprocessed_symptoms2 = " ".join(preprocessed_symptoms2)
user2 = cv.transform([preprocessed_symptoms2])
predict1 = clf.predict(user2)
print("Disease:", predict1)
predict2=predict1[0]
mat = rg[rg["Disease"] == predict2]
dia = mat.All_Precautions.values[0]
print("Precautions:" , dia)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 4
#       2 preprocessed_symptoms2 = " ".join(preprocessed_symptoms2)
#       3 user2 = cv.transform([preprocessed_symptoms2])
# ----> 4 predict1 = clf.predict(user2)
#       5 print("Disease:", predict1)
#       6 predict2=predict1[0]
#
# File c:\Users\ayush\OneDrive\Desktop\Healthcare-Chatbot-main\venv\lib\site-packages\sklearn\svm\_base.py:810, in BaseSVC.predict(self, X)
#     808     y = np.argmax(self.decision_function(X), axis=1)
#     809 else:
# --> 810     y = super().predict(X)
#     811 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File c:\Users\ayush\OneDrive\Desktop\Healthcare-Chatbot-main\venv\lib\site-packages\sklearn\svm\_base.py:433, in BaseLibSVM.predict(self, X)
#     417 def predict(self, X):
#     418     """Perform regression on samples in X.
#     419
#     420     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     431         The predicted values.
#     432     """
# --> 433     X = self._validate_for_predict(X)
#     434     predict = self._sparse_predict if self._sparse else self._dense_predict
#     435     return predict(X)
#
# File c:\Users\ayush\OneDrive\Desktop\Healthcare-Chatbot-main\venv\lib\site-packages\sklearn\svm\_base.py:611, in BaseLibSVM._validate_for_predict(self, X)
#     608 check_is_fitted(self)
#     610 if not callable(self.kernel):
# --> 611     X = self._validate_data(
#     612         X,
#     613         accept_sparse="csr",
#     614         dtype=np.float64,
#     615         order="C",
#     616         accept_large_sparse=False,
#     617         reset=False,
#     618     )
#     620 if self._sparse and not sp.isspmatrix(X):
#     621     X = sp.csr_matrix(X)
#
# File c:\Users\ayush\OneDrive\Desktop\Healthcare-Chatbot-main\venv\lib\site-packages\sklearn\base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File c:\Users\ayush\OneDrive\Desktop\Healthcare-Chatbot-main\venv\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 195 features, but SVC is expecting 200 features as input.

# %%
preprocessed_symptoms2 = preprocess_text("I have back pain dizziness vomiting stomach pain ")
preprocessed_symptoms2 = " ".join(preprocessed_symptoms2)
user2 = cv1.transform([preprocessed_symptoms2])
predict1 = clf.predict(user2)
print("Disease:", predict1)
predict2=predict1[0]
mat = rg[rg["Disease"] == predict2]
dia = mat.All_Precautions.values[0]
print("Precautions:" , dia)
# Out:
# Disease: ['Cervical spondylosis']
# Precautions: The precautions to take: use heating pad or cold pack,exercise,take otc pain reliver,consult doctor

# %%
rg.head()
# Out:
#             Disease                                       All_Symptoms  \
# 0  Fungal infection  itching skin rash nodal skin eruptions dischro...
# 1  Fungal infection  skin rash nodal skin eruptions dischromic patches
# 2  Fungal infection    itching nodal skin eruptions dischromic patches
# 3  Fungal infection               itching skin rash dischromic patches
# 4  Fungal infection             itching skin rash nodal skin eruptions
#
#                                      All_Precautions
# 0  The precautions to take: bath twice,use detol ...
# 1  The precautions to take: bath twice,use detol ...
# 2  The precautions to take: bath twice,use detol ...
# 3  The precautions to take: bath twice,use detol ...
# 4  The precautions to take: bath twice,use detol ...

# %%
def nlp_model(x):
    preprocessed_symptoms = preprocess_text(x)
    preprocessed_symptoms = " ".join(preprocessed_symptoms)
    symptom_vector = cv.transform([preprocessed_symptoms])
    res1 = rnd_forest.predict(symptom_vector)
    res2=res1[0]
    mat1 = rg[rg["Disease"] == res2]
    dia1 = mat1.All_Precautions.values[0]
    print("The Diagonisis Result: ")
    print("Disease: ",res2)
    print("Precautions:" , dia1)
    
    inp = input("Do you wanna know anything about any disease(yes/no): ")
    if inp == "yes":
        dis = input("Enter the disease: ")
        print("Your entered disease: ", dis)
        mat = rg[rg["Disease"] == dis]
        print("You may have suffered from the following symptoms: ")
        sym = mat.All_Symptoms.values[0]
        print(sym)
        print("The Precautions of your disease are - ")
        dia = mat.All_Precautions.values[0]
        print(dia)
        
    else:
        print("Get well soon!!")

# %%
user = input("Enter Your Symptoms(atlest 3/4 symptoms needed): ")

# %%
nlp_model(user)
# Out:
# The Diagonisis Result:
# Disease:  ['Acne']
# Precautions: The precautions to take: bath twice,use detol or neem in bathing water,keep infected area dry,use clean cloths
# Your entered disease:  Acne
# You may have suffered from the following symptoms:
# skin rash pus filled pimples blackheads scurring
# The Precautions of your disease are -
# The precautions to take: bath twice,avoid fatty spicy food,drink plenty of water,avoid too many products
